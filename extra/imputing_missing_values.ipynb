# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.impute import SimpleImputer
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('df18to21_cleaned.csv')

# %%
df.head(2)
# Out:
#    Unnamed: 0  sentence_length  year_sentenced  sentence_type  \
# 0       12990              188            2018              1
# 1       14616                0            2018              1
#
#    guideline_range  imprisoned  guideline_var_pct  dependents  \
# 0              1.0           1                NaN           1
# 1              NaN           1                NaN           1
#
#    count_convictons  race  education  disposition  citizen     state  \
# 0                 1     1        1.0            3        1      Utah
# 1                 1     1        NaN            1        0  Virginia
#
#    criminal_hist  drug_type  case_type   age  weapon  presentence_stat  \
# 0            1.0        3.0        1.0  24.0       0               1.0
# 1            1.0        NaN        NaN  28.0       0               1.0
#
#    gender  crime_type region  college  white  perc_charged
# 0     0.0          10   West        0      1      0.079034
# ...

# %% [markdown]
# Strategy for dealing with null values:
#
# - 'guideline_range' - no need to impute
# - 'guideline_var_pct' - no need to impute
# - 'criminal_hist' - impute with mode
# - 'case_type' - impute with mode
# - 'age' - impute with mean
# - 'presentence_stat' - no need to impute
# - 'gender' - impute with mode
#
# - ‘guideline_range’ - no need to impute
#     LETS FILL WITH 0, CREATING NEW CATEGORY FOR SENTENCES OUTSIDE RANGE, WILL BE OHE
# - ‘guideline_var_pct’ - no need to impute
#     LETS FILL WITH 0, NO DEVIATION FROM GUIDELINES
# - ‘guideline_var_mth’ - no need to impute
#   LETS FILL WITH 0, NO DEVIATION FROM GUIDELINES

# %%
df['age'].fillna(df['age'].mean(), inplace=True)  

df['criminal_hist'].fillna(df['criminal_hist'].mode()[0], inplace=True)    
df['case_type'].fillna(df['case_type'].mode()[0], inplace=True)    
df['gender'].fillna(df['gender'].mode()[0], inplace=True)   

df['drug_type'].fillna(0, inplace=True)
df['presentence_stat'].fillna(1, inplace=True)
df['guideline_range'].fillna(0, inplace=True)
df['guideline_var_pct'].fillna(0, inplace=True)

# %%
df.drop(columns='education', inplace=True)

# %%
df.to_csv('./NEWSAVE/df18to21_cleaned.csv')

# %%
df.head(20)
# Out:
#     Unnamed: 0  sentence_length  year_sentenced  sentence_type  \
# 0        12990              188            2018              1
# 1        14616                0            2018              1
# 2        14617              300            2018              1
# 3        14619               63            2018              1
# 4        14620                0            2018              1
# 5        14621               10            2018              1
# 6        14622                0            2018              4
# 7        14623                0            2018              1
# 8        14624                8            2018              1
# 9        14625               90            2018              1
# 10       14626               92            2018              1
# 11       14627               41            2018              1
# 12       14628               90            2018              1
# 13       14676               12            2018              1
# ...
